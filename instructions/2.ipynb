# %% [markdown]
# Registration of Upright and Tilt in riscan pro. Leveling U using the inclination sensors; location set to 0,0,0 and use of reflector to link T with U. All SOPs are exported to the matrix folder.

# %% [markdown]
# # List all the plots

# %%
# %%bash
# pwd
# find ../../?????? -type d -maxdepth 0 -not -name "matrix" > in.txt
#
# more in.txt
# Out:
# /Stor1/kim_new/formica/profiles/instructions
# ::::::::::::::
# in.txt
# ::::::::::::::
# ../../BeHiT1
# ../../BeHiT2
# ../../BeHiT3
# ../../BeLoT1
# ../../BeLoT2
# ../../BeLoT3
# ../../BeMeT1
# ../../BeMeT2
# ../../BeMeT3
# ../../FrLoT1
# ../../FrLoT2
# ../../FrLoT3
# ../../GeLoT1
# ../../GeLoT2
# ../../GeLoT3
# ../../ItHiT1
# ../../ItHiT2
# ../../ItHiT3
# ../../ItLoT1
# ../../ItLoT2
# ../../ItLoT3
# ../../ItMeT1
# ../../ItMeT2
# ../../ItMeT3
# ../../NoHiT1
# ../../NoHiT2
# ../../NoHiT3
# ../../NoLoT1
# ../../NoLoT2
# ../../NoLoT3
# ../../NoMeT1
# ../../NoMeT2
# ../../NoMeT3
# ../../PoLoT1
# ../../PoLoT2
# ../../PoLoT3
# ../../SwLoT1
# ../../SwLoT2
# ../../SwLoT3

# %% [markdown]
# # Make profiles

# %% [markdown]
# # Canopy profiles: combining upright and tilted scan

# %% [markdown]
# First we need to convert the individual scans to spd; then we need to generate the profile:

# %%
# %%bash
# #pwd
# mkdir ../reports
# mkdir ../profiles
# mkdir ../commands
# mkdir ../plots
# source activate lidar #activate anaconda lidar env
# cat in.txt | while read line
# do
#     plot=$(basename $line)
#     echo "processing $plot"
#
#     #location 1:
#     up_rxp=$line/*riproject/ScanPos001/??????_??????.rxp
#     up_matrix=../../matrix/$plot/ScanPos001.DAT
#     tilt_rxp=$line/*riproject/ScanPos002/??????_??????.rxp
#     tilt_matrix=../../matrix/$plot/ScanPos002.DAT
#     vpf=vpf.$plot.location1.zen5_70.csv
#     plane_report=plane.$plot.location1.rpt
#     com=command.$plot.location1.txt
#     echo pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60 > ../commands/$com
#     pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60
#
#     #location 2:
#     up_rxp=$line/*riproject/ScanPos003/??????_??????.rxp
#     up_matrix=../../matrix/$plot/ScanPos003.DAT
#     tilt_rxp=$line/*riproject/ScanPos004/??????_??????.rxp
#     tilt_matrix=../../matrix/$plot/ScanPos004.DAT
#     vpf=vpf.$plot.location2.zen5_70.csv
#     plane_report=plane.$plot.location2.rpt
#     com=command.$plot.location2.txt
#     echo pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60 > ../commands/$com
#     pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60
#
#     #location 3:
#     up_rxp=$line/*riproject/ScanPos005/??????_??????.rxp
#     up_matrix=../../matrix/$plot/ScanPos005.DAT
#     tilt_rxp=$line/*riproject/ScanPos006/??????_??????.rxp
#     tilt_matrix=../../matrix/$plot/ScanPos006.DAT
#     vpf=vpf.$plot.location3.zen5_70.csv
#     plane_report=plane.$plot.location3.rpt
#     com=command.$plot.location3.txt
#     echo pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60 > ../commands/$com
#     pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60
#
#     #location 4:
#     up_rxp=$line/*riproject/ScanPos007/??????_??????.rxp
#     up_matrix=../../matrix/$plot/ScanPos007.DAT
#     tilt_rxp=$line/*riproject/ScanPos008/??????_??????.rxp
#     tilt_matrix=../../matrix/$plot/ScanPos008.DAT
#     vpf=vpf.$plot.location4.zen5_70.csv
#     plane_report=plane.$plot.location4.rpt
#     com=command.$plot.location4.txt
#     echo pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60 > ../commands/$com
#     pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60
#
#     #location 5:
#     up_rxp=$line/*riproject/ScanPos009/??????_??????.rxp
#     up_matrix=../../matrix/$plot/ScanPos009.DAT
#     tilt_rxp=$line/*riproject/ScanPos010/??????_??????.rxp
#     tilt_matrix=../../matrix/$plot/ScanPos010.DAT
#     vpf=vpf.$plot.location5.zen5_70.csv
#     plane_report=plane.$plot.location5.rpt
#     com=command.$plot.location5.txt
#     echo pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60 > ../commands/$com
#     pylidar_canopy -m PAVD_CALDERS2014 -i $up_rxp $tilt_rxp -o ../profiles/$vpf --gridsize 10 --minazimuth 0 0 --maxazimuth 360 360 --minzenith 35.0 5.0 --maxzenith 70.0 35.0 --externaltransformfn $up_matrix $tilt_matrix --weighted --planecorrection --reportfile ../reports/$plane_report --minheight 0 --maxheight 60
#
# done
# Out:
# processing BeHiT1
# Applying plane correction to point heights...
# .wfm file not found. Use "rxp2wfm -i" to extract first.
# .wfm file not found. Use "rxp2wfm -i" to extract first.
#
# Calculating vertical plant profiles...
# .wfm file not found. Use "rxp2wfm -i" to extract first.
# .wfm file not found. Use "rxp2wfm -i" to extract first.
#
# Applying plane correction to point heights...
# .wfm file not found. Use "rxp2wfm -i" to extract first.
# .wfm file not found. Use "rxp2wfm -i" to extract first.
#
# Calculating vertical plant profiles...
# .wfm file not found. Use "rxp2wfm -i" to extract first.
# .wfm file not found. Use "rxp2wfm -i" to extract first.
#
# Applying plane correction to point heights...
# .wfm file not found. Use "rxp2wfm -i" to extract first.
# .wfm file not found. Use "rxp2wfm -i" to extract first.
#
# Calculating vertical plant profiles...
# .wfm file not found. Use "rxp2wfm -i" to extract first.
# .wfm file not found. Use "rxp2wfm -i" to extract first.
#
# ...

# %% [markdown]
# # Plot profiles and make summary file

# %%
import glob
import csv
import matplotlib.pyplot as plt
import numpy as np

location = "../profiles/"
plotloc = "../plots/"
files=glob.glob(location+"vpf*csv")

PAIe_all=([])
loc_all=([])

for file in files:
    print("Analysing height corrected profile %s \n" %file)
    reader=csv.reader(open(file), delimiter=",")
    firstLine=True
    height=PAIe=PAVD=lin_PAI=lin_PAVD=np.array([])
    for row in reader:
        if firstLine:
            firstLine=False
        else:
            height=np.append(height,float(row[0]))
            PAIe=np.append(PAIe,float(row[-2]))
            PAVD=np.append(PAVD,float(row[-1]))
            lin_PAVD=np.append(lin_PAVD,float(row[-4]))
    PAIe_all.append([max(PAIe)])
    loc_all.append([file.split("/")[-1].split("_")[0]])

    fig = plt.figure()
    plt.plot(PAVD,height, label="Jupp et al. (2009)",color='b')
#    plt.plot(lin_PAVD,height, label="Linear", color='r')
    plt.xlabel('PAVD [m2/m3]')
    plt.ylabel('Canopy height [m]')
    plt.title('PAVD profile for %s' % file.split("/")[-1].split(".csv")[0])
    plt.ylim(0,35)
    plt.legend()
#    plt.show()
    fig.savefig("%s%s.png" %(plotloc,file.split("/")[-1].split(".csv")[0]),dpi=600)
    plt.close(fig)

    
summary=np.hstack([loc_all,PAIe_all])
np.savetxt("%ssummary.csv" %(location),summary,header="location,PAIe",fmt="%s",delimiter=",")
# Out:
# Analysing height corrected profile ../profiles/vpf.BeHiT1.location1.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT1.location2.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT1.location3.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT1.location4.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT1.location5.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT2.location1.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT2.location2.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT2.location3.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT2.location4.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT2.location5.zen5_70.csv
#
# Analysing height corrected profile ../profiles/vpf.BeHiT3.location1.zen5_70.csv
#
# ...
